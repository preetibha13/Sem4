# %%
import pandas as pd
import numpy as np

# %%
nba=pd.read_csv(r"C:\Users\Preeti\Desktop\Preeti\Christ\Excel files (python)\nba.csv")
nba
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
# 591                NaN                 NaN      NaN    NaN     NaN
#
#            College      Salary
# 0        Villanova   4556983.0
# 1       Fenerbahce  18700000.0
# 2         Michigan   4094244.0
# 3      Elan Chalon  20616000.0
# ...

# %%
nba.dropna()
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 585     Eugene Omoruyi  Washington Wizards        F    6-6   235.0
# 586       Jordan Poole  Washington Wizards        G    6-4   194.0
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
#
#            College      Salary
# 0        Villanova   4556983.0
# 1       Fenerbahce  18700000.0
# 2         Michigan   4094244.0
# 3      Elan Chalon  20616000.0
# ...

# %%
nba.dropna(how="all") # all rows with na value
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 586       Jordan Poole  Washington Wizards        G    6-4   194.0
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
#
#            College      Salary
# 0        Villanova   4556983.0
# 1       Fenerbahce  18700000.0
# 2         Michigan   4094244.0
# 3      Elan Chalon  20616000.0
# ...

# %%
nba.dropna(subset="Salary")
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 585     Eugene Omoruyi  Washington Wizards        F    6-6   235.0
# 586       Jordan Poole  Washington Wizards        G    6-4   194.0
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
#
#            College      Salary
# 0        Villanova   4556983.0
# 1       Fenerbahce  18700000.0
# 2         Michigan   4094244.0
# 3      Elan Chalon  20616000.0
# ...

# %%
nba.dropna(subset=["College","Salary"])
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 585     Eugene Omoruyi  Washington Wizards        F    6-6   235.0
# 586       Jordan Poole  Washington Wizards        G    6-4   194.0
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
#
#            College      Salary
# 0        Villanova   4556983.0
# 1       Fenerbahce  18700000.0
# 2         Michigan   4094244.0
# 3      Elan Chalon  20616000.0
# ...

# %%
nba.Salary=nba.Salary.fillna(0)

# %%
nba
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
# 591                NaN                 NaN      NaN    NaN     NaN
#
#            College      Salary
# 0        Villanova   4556983.0
# 1       Fenerbahce  18700000.0
# 2         Michigan   4094244.0
# 3      Elan Chalon  20616000.0
# ...

# %%
nba.College=nba.College.fillna("Unknown")

# %%
nba
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
# 591                NaN                 NaN      NaN    NaN     NaN
#
#            College      Salary
# 0        Villanova   4556983.0
# 1       Fenerbahce  18700000.0
# 2         Michigan   4094244.0
# 3      Elan Chalon  20616000.0
# ...

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 592 entries, 0 to 591
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      591 non-null    object
#  1   Team      591 non-null    object
#  2   Position  584 non-null    object
#  3   Height    585 non-null    object
#  4   Weight    584 non-null    float64
#  5   College   592 non-null    object
#  6   Salary    592 non-null    float64
# dtypes: float64(2), object(5)
# memory usage: 32.5+ KB

# %%
nba.describe()   # math operations
# Out:
#            Weight        Salary
# count  584.000000  5.920000e+02
# mean   214.763699  7.599428e+06
# std     23.460612  1.085853e+07
# min    160.000000  0.000000e+00
# 25%    198.000000  5.597820e+05
# 50%    215.000000  2.774337e+06
# 75%    230.000000  9.525000e+06
# max    290.000000  5.191562e+07

# %%
nba.loc[:,["Name","Position","Salary"]].head()  # filtering
# Out:
#                 Name Position      Salary
# 0         Saddiq Bey        F   4556983.0
# 1  Bogdan Bogdanovic        G  18700000.0
# 2        Kobe Bufkin        G   4094244.0
# 3       Clint Capela        C  20616000.0
# 4     Bruno Fernando      F-C   2581522.0

# %%
nba.loc[nba["Position"]=="F"].head()
# Out:
#               Name            Team Position Height  Weight           College  \
# 0       Saddiq Bey   Atlanta Hawks        F    6-7   215.0         Villanova
# 6       AJ Griffin   Atlanta Hawks        F    6-6   220.0              Duke
# 7   Mouhamed Gueye   Atlanta Hawks        F   6-11   210.0  Washington State
# 9    Jalen Johnson   Atlanta Hawks        F    6-8   219.0              Duke
# 18   Dalano Banton  Boston Celtics        F    6-7   204.0          Nebraska
#
#        Salary
# 0   4556983.0
# 6   3712920.0
# 7   1119563.0
# 9   2925360.0
# 18  2019706.0

# %%
nba.loc[nba["Team"]=="Atlanta Hawks"]
# Out:
#                  Name           Team Position Height  Weight  \
# 0          Saddiq Bey  Atlanta Hawks        F    6-7   215.0
# 1   Bogdan Bogdanovic  Atlanta Hawks        G    6-5   225.0
# 2         Kobe Bufkin  Atlanta Hawks        G    6-5   195.0
# 3        Clint Capela  Atlanta Hawks        C   6-10   256.0
# 4      Bruno Fernando  Atlanta Hawks      F-C   6-10   240.0
# 5       Trent Forrest  Atlanta Hawks        G    6-4   210.0
# 6          AJ Griffin  Atlanta Hawks        F    6-6   220.0
# 7      Mouhamed Gueye  Atlanta Hawks        F   6-11   210.0
# 8     De'Andre Hunter  Atlanta Hawks      F-G    6-8   221.0
# 9       Jalen Johnson  Atlanta Hawks        F    6-8   219.0
# 10         Seth Lundy  Atlanta Hawks        G    6-6   220.0
# 11   Garrison Mathews  Atlanta Hawks        G    6-6   215.0
# 12    Wesley Matthews  Atlanta Hawks        G    6-5   220.0
# 13        Patty Mills  Atlanta Hawks        G    6-0   180.0
# ...

# %%
nba["salaryin"]=nba["Salary"]*1.05

# %%
nba["salaryin"]
# Out:
# 0       4784832.15
# 1      19635000.00
# 2       4298956.20
# 3      21646800.00
# 4       2710598.10
#           ...
# 587     1805857.20
# 588    10762500.00
# 589           0.00
# 590     8604878.10
# 591           0.00
# Name: salaryin, Length: 592, dtype: float64

# %%
nba["Salary_in"]=nba["Salary"]*1.05
nba     # now the change is in the whole file
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
# 591                NaN                 NaN      NaN    NaN     NaN
#
#            College      Salary     salaryin    Salary_in
# 0        Villanova   4556983.0   4784832.15   4784832.15
# ...

# %%
nba
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
# 591                NaN                 NaN      NaN    NaN     NaN
#
#            College      Salary     salaryin    Salary_in
# 0        Villanova   4556983.0   4784832.15   4784832.15
# ...

# %%
# dataframe

# %%
data={"Fruits":["Apple","Banana","Grapes","Orange"],"kgs":[1,3,4,7],"Condition":["Good","Bad","Bad","Good"]}

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#    Fruits  kgs Condition
# 0   Apple    1      Good
# 1  Banana    3       Bad
# 2  Grapes    4       Bad
# 3  Orange    7      Good

# %%
df.loc[df["Condition"]=="Bad"]
# Out:
#    Fruits  kgs Condition
# 1  Banana    3       Bad
# 2  Grapes    4       Bad

# %%
df.loc[df["Condition"]=="Good"]
# Out:
#    Fruits  kgs Condition
# 0   Apple    1      Good
# 3  Orange    7      Good

# %%
df
# Out:
#    Fruits  kgs Condition
# 0   Apple    1      Good
# 1  Banana    3       Bad
# 2  Grapes    4       Bad
# 3  Orange    7      Good

# %%
nba
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
# 591                NaN                 NaN      NaN    NaN     NaN
#
#            College      Salary     salaryin    Salary_in
# 0        Villanova   4556983.0   4784832.15   4784832.15
# ...

# %%
nba=nba.dropna(subset="Name")  # this way there is change in the actual data

# %%
nba
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 586       Jordan Poole  Washington Wizards        G    6-4   194.0
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
#
#            College      Salary     salaryin    Salary_in
# 0        Villanova   4556983.0   4784832.15   4784832.15
# ...

# %%
# conditional &
nba[(nba["Weight"]<300)& (nba["Weight"]>250)]
# Out:
#                    Name                    Team Position Height  Weight  \
# 3          Clint Capela           Atlanta Hawks        C   6-10   256.0
# 45       Day'Ron Sharpe           Brooklyn Nets        C    6-9   265.0
# 80       Andre Drummond           Chicago Bulls        C   6-11   279.0
# 89       Nikola Vucevic           Chicago Bulls        C   6-10   260.0
# 145        Nikola Jokic          Denver Nuggets        C   6-11   284.0
# 146      DeAndre Jordan          Denver Nuggets        C   6-11   265.0
# 200        Jock Landale         Houston Rockets        C   6-11   255.0
# 228      Oscar Tshiebwe          Indiana Pacers      F-C    6-9   255.0
# 247       Mason Plumlee    Los Angeles Clippers      F-C    7-0   254.0
# 254       Anthony Davis      Los Angeles Lakers      F-C   6-10   253.0
# 268    Tristan Thompson      Los Angeles Lakers      C-F    6-9   254.0
# 271        Steven Adams       Memphis Grizzlies        C   6-11   265.0
# ...

# %%
nba[(nba["Position"]=="C")]
# Out:
#                   Name                    Team Position Height  Weight  \
# 3         Clint Capela           Atlanta Hawks        C   6-10   256.0
# 26   Mfiondu Kabengele          Boston Celtics        C   6-10   250.0
# 39         Nic Claxton           Brooklyn Nets        C   6-11   215.0
# 45      Day'Ron Sharpe           Brooklyn Nets        C    6-9   265.0
# 67       Nick Richards       Charlotte Hornets        C    7-0   245.0
# 72       Mark Williams       Charlotte Hornets        C    7-0   240.0
# 80      Andre Drummond           Chicago Bulls        C   6-11   279.0
# 89      Nikola Vucevic           Chicago Bulls        C   6-10   260.0
# 92       Jarrett Allen     Cleveland Cavaliers        C    6-9   243.0
# 98        Damian Jones     Cleveland Cavaliers        C   6-11   245.0
# 102        Evan Mobley     Cleveland Cavaliers        C   6-11   215.0
# 123   Dereck Lively II        Dallas Mavericks        C    7-1   230.0
# ...
