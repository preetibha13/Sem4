# %%
import pandas as pd

# %%
import numpy as np

# %%
nba=pd.read_csv(r"C:\Users\Preeti\Desktop\Preeti\Christ\Excel files (python)\nba.csv")
nba
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
# 591                NaN                 NaN      NaN    NaN     NaN
#
#            College      Salary
# 0        Villanova   4556983.0
# 1       Fenerbahce  18700000.0
# 2         Michigan   4094244.0
# 3      Elan Chalon  20616000.0
# ...

# %%
nba.dropna()
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 585     Eugene Omoruyi  Washington Wizards        F    6-6   235.0
# 586       Jordan Poole  Washington Wizards        G    6-4   194.0
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
#
#            College      Salary
# 0        Villanova   4556983.0
# 1       Fenerbahce  18700000.0
# 2         Michigan   4094244.0
# 3      Elan Chalon  20616000.0
# ...

# %%
nba.dropna(how="all")
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 586       Jordan Poole  Washington Wizards        G    6-4   194.0
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
#
#            College      Salary
# 0        Villanova   4556983.0
# 1       Fenerbahce  18700000.0
# 2         Michigan   4094244.0
# 3      Elan Chalon  20616000.0
# ...

# %%
nba.dropna(subset=["Name","Salary"])
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 585     Eugene Omoruyi  Washington Wizards        F    6-6   235.0
# 586       Jordan Poole  Washington Wizards        G    6-4   194.0
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
#
#            College      Salary
# 0        Villanova   4556983.0
# 1       Fenerbahce  18700000.0
# 2         Michigan   4094244.0
# 3      Elan Chalon  20616000.0
# ...

# %%
nba.Salary=nba.Salary.fillna("To be decided")
nba
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
# 591                NaN                 NaN      NaN    NaN     NaN
#
#            College         Salary
# 0        Villanova      4556983.0
# 1       Fenerbahce     18700000.0
# 2         Michigan      4094244.0
# ...

# %%
nba.Salary.unique
# Out:
# <bound method Series.unique of 0          4556983.0
# 1         18700000.0
# 2          4094244.0
# 3         20616000.0
# 4          2581522.0
#            ...
# 587        1719864.0
# 588       10250000.0
# 589    To be decided
# 590        8195122.0
# 591    To be decided
# Name: Salary, Length: 592, dtype: object>

# %%
nba.Salary.describe()
# Out:
# count               592
# unique              299
# top       To be decided
# freq                104
# Name: Salary, dtype: object

# %%
nba.Salary.unique()
# Out:
# array([4556983.0, 18700000.0, 4094244.0, 20616000.0, 2581522.0, 508891.0,
#        3712920.0, 1119563.0, 20089286.0, 2925360.0, 559782.0, 2000000.0,
#        3196448.0, 6802950.0, 18214000.0, 8109063.0, 40064220.0, 2019706.0,
#        2165000.0, 22500000.0, 31830357.0, 'To be decided', 1927896.0,
#        10000000.0, 2413304.0, 36016200.0, 4037277.0, 32600060.0,
#        18357143.0, 21700000.0, 3089460.0, 20357143.0, 13932008.0,
#        25679348.0, 9500000.0, 2210040.0, 37893408.0, 2240160.0, 2966040.0,
#        10900635.0, 4570080.0, 7921300.0, 31500000.0, 3047880.0, 7560000.0,
#        1719864.0, 10880364.0, 2528233.0, 23205221.0, 1836096.0, 3908160.0,
#        20465117.0, 6190476.0, 9460000.0, 28600000.0, 6481482.0, 3360000.0,
#        1600000.0, 3350760.0, 18518519.0, 11111111.0, 9835881.0,
#        20000000.0, 34005250.0, 2439025.0, 2586665.0, 15384616.0,
#        1997238.0, 33162030.0, 8882640.0, 8800000.0, 8920794.0, 6146342.0,
# ...

# %%
nba.Team=nba.Team.replace(to_replace=["Atlanta Hawks"], value=["AtlantaHawks"])
nba
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey        AtlantaHawks        F    6-7   215.0
# 1    Bogdan Bogdanovic        AtlantaHawks        G    6-5   225.0
# 2          Kobe Bufkin        AtlantaHawks        G    6-5   195.0
# 3         Clint Capela        AtlantaHawks        C   6-10   256.0
# 4       Bruno Fernando        AtlantaHawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
# 591                NaN                 NaN      NaN    NaN     NaN
#
#            College         Salary
# 0        Villanova      4556983.0
# 1       Fenerbahce     18700000.0
# 2         Michigan      4094244.0
# ...

# %%
nba.rename(columns={"Team":"Team Name"},inplace=True)
nba
# Out:
#                   Name           Team Name Position Height  Weight  \
# 0           Saddiq Bey        AtlantaHawks        F    6-7   215.0
# 1    Bogdan Bogdanovic        AtlantaHawks        G    6-5   225.0
# 2          Kobe Bufkin        AtlantaHawks        G    6-5   195.0
# 3         Clint Capela        AtlantaHawks        C   6-10   256.0
# 4       Bruno Fernando        AtlantaHawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
# 591                NaN                 NaN      NaN    NaN     NaN
#
#            College         Salary
# 0        Villanova      4556983.0
# 1       Fenerbahce     18700000.0
# 2         Michigan      4094244.0
# ...

# %%
nba.loc[:,["Name","College","Salary"]]
# Out:
#                   Name        College         Salary
# 0           Saddiq Bey      Villanova      4556983.0
# 1    Bogdan Bogdanovic     Fenerbahce     18700000.0
# 2          Kobe Bufkin       Michigan      4094244.0
# 3         Clint Capela    Elan Chalon     20616000.0
# 4       Bruno Fernando       Maryland      2581522.0
# ..                 ...            ...            ...
# 587       Ryan Rollins         Toledo      1719864.0
# 588      Landry Shamet  Wichita State     10250000.0
# 589   Tristan Vukcevic    Real Madrid  To be decided
# 590       Delon Wright           Utah      8195122.0
# 591                NaN            NaN  To be decided
#
# [592 rows x 3 columns]

# %%
nba.loc[nba["Position"]=="G",["Name","Salary","Position"]]
# Out:
#                   Name         Salary Position
# 1    Bogdan Bogdanovic     18700000.0        G
# 2          Kobe Bufkin      4094244.0        G
# 5        Trent Forrest       508891.0        G
# 10          Seth Lundy       559782.0        G
# 11    Garrison Mathews      2000000.0        G
# ..                 ...            ...      ...
# 584      Kendrick Nunn  To be decided        G
# 586       Jordan Poole     27955357.0        G
# 587       Ryan Rollins      1719864.0        G
# 588      Landry Shamet     10250000.0        G
# 590       Delon Wright      8195122.0        G
#
# [229 rows x 3 columns]

# %%
nba.loc[nba["Team Name"]=="AtlantaHawks",["Name","Position","Salary"]]
# Out:
#                  Name Position      Salary
# 0          Saddiq Bey        F   4556983.0
# 1   Bogdan Bogdanovic        G  18700000.0
# 2         Kobe Bufkin        G   4094244.0
# 3        Clint Capela        C  20616000.0
# 4      Bruno Fernando      F-C   2581522.0
# 5       Trent Forrest        G    508891.0
# 6          AJ Griffin        F   3712920.0
# 7      Mouhamed Gueye        F   1119563.0
# 8     De'Andre Hunter      F-G  20089286.0
# 9       Jalen Johnson        F   2925360.0
# 10         Seth Lundy        G    559782.0
# 11   Garrison Mathews        G   2000000.0
# 12    Wesley Matthews        G   3196448.0
# 13        Patty Mills        G   6802950.0
# 14    Dejounte Murray        G  18214000.0
# 15       Miles Norris      NaN    559782.0
# 16     Onyeka Okongwu      F-C   8109063.0
# 17         Trae Young        G  40064220.0
