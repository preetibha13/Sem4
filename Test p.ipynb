# %% [raw]
# import pandas as pd
# import numpy as np

# %%
nba=pd.read_csv(r"C:\Users\Preeti\Desktop\Preeti\Christ\Excel files (python)\nba.csv")
nba
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
# 591                NaN                 NaN      NaN    NaN     NaN
#
#            College      Salary
# 0        Villanova   4556983.0
# 1       Fenerbahce  18700000.0
# 2         Michigan   4094244.0
# 3      Elan Chalon  20616000.0
# ...

# %%
nba.dropna()
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 585     Eugene Omoruyi  Washington Wizards        F    6-6   235.0
# 586       Jordan Poole  Washington Wizards        G    6-4   194.0
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
#
#            College      Salary
# 0        Villanova   4556983.0
# 1       Fenerbahce  18700000.0
# 2         Michigan   4094244.0
# 3      Elan Chalon  20616000.0
# ...

# %%
nba.dropna(how="all")
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 586       Jordan Poole  Washington Wizards        G    6-4   194.0
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
#
#            College      Salary
# 0        Villanova   4556983.0
# 1       Fenerbahce  18700000.0
# 2         Michigan   4094244.0
# 3      Elan Chalon  20616000.0
# ...

# %%
nba.dropna(subset=["College","Salary","Name"])
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 585     Eugene Omoruyi  Washington Wizards        F    6-6   235.0
# 586       Jordan Poole  Washington Wizards        G    6-4   194.0
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
#
#            College      Salary
# 0        Villanova   4556983.0
# 1       Fenerbahce  18700000.0
# 2         Michigan   4094244.0
# 3      Elan Chalon  20616000.0
# ...

# %%
nba.Salary=nba.Salary.fillna("To be decided")

# %%
nba.Salary
# Out:
# 0          4556983.0
# 1         18700000.0
# 2          4094244.0
# 3         20616000.0
# 4          2581522.0
#            ...
# 587        1719864.0
# 588       10250000.0
# 589    To be decided
# 590        8195122.0
# 591    To be decided
# Name: Salary, Length: 592, dtype: object

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 592 entries, 0 to 591
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      591 non-null    object
#  1   Team      591 non-null    object
#  2   Position  584 non-null    object
#  3   Height    585 non-null    object
#  4   Weight    584 non-null    float64
#  5   College   578 non-null    object
#  6   Salary    592 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 32.5+ KB

# %%
nba.describe()
# Out:
#            Weight
# count  584.000000
# mean   214.763699
# std     23.460612
# min    160.000000
# 25%    198.000000
# 50%    215.000000
# 75%    230.000000
# max    290.000000

# %%
nba.loc[:,["Name","Salary","Position"]]
# Out:
#                   Name         Salary Position
# 0           Saddiq Bey      4556983.0        F
# 1    Bogdan Bogdanovic     18700000.0        G
# 2          Kobe Bufkin      4094244.0        G
# 3         Clint Capela     20616000.0        C
# 4       Bruno Fernando      2581522.0      F-C
# ..                 ...            ...      ...
# 587       Ryan Rollins      1719864.0        G
# 588      Landry Shamet     10250000.0        G
# 589   Tristan Vukcevic  To be decided        F
# 590       Delon Wright      8195122.0        G
# 591                NaN  To be decided      NaN
#
# [592 rows x 3 columns]

# %%
nba.loc[nba["Position"]=="G",["Name","Salary","College"]]
# Out:
#                   Name         Salary        College
# 1    Bogdan Bogdanovic     18700000.0     Fenerbahce
# 2          Kobe Bufkin      4094244.0       Michigan
# 5        Trent Forrest       508891.0  Florida State
# 10          Seth Lundy       559782.0     Penn State
# 11    Garrison Mathews      2000000.0       Lipscomb
# ..                 ...            ...            ...
# 584      Kendrick Nunn  To be decided        Oakland
# 586       Jordan Poole     27955357.0       Michigan
# 587       Ryan Rollins      1719864.0         Toledo
# 588      Landry Shamet     10250000.0  Wichita State
# 590       Delon Wright      8195122.0           Utah
#
# [229 rows x 3 columns]

# %%
nba["Salary_in"]=nba["Salary"]*2
nba
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
# 591                NaN                 NaN      NaN    NaN     NaN
#
#            College         Salary                   Salary_in
# 0        Villanova      4556983.0                   9113966.0
# ...

# %%
nba.rename(columns={"Salary_in":"New_salary"},inplace=True)

# %%
nba
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
# 591                NaN                 NaN      NaN    NaN     NaN
#
#            College         Salary                  New_salary
# 0        Villanova      4556983.0                   9113966.0
# ...

# %%
nba.rename(columns={"Team":"College Name"},inplace=True)

# %%
nba
# Out:
#                   Name        College Name Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
# 591                NaN                 NaN      NaN    NaN     NaN
#
#            College         Salary                  New_salary
# 0        Villanova      4556983.0                   9113966.0
# ...

# %%
nba.rename(columns={"College Name":"College Team"},inplace=True)

# %%
nba
# Out:
#                   Name        College Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
# 591                NaN                 NaN      NaN    NaN     NaN
#
#            College         Salary                  New_salary
# 0        Villanova      4556983.0                   9113966.0
# ...

# %%
Table={"Name":["Preeti","Abhi",np.nan,"Aditi"],"Marks":[78,87,95,34],"Grade":["A","A","B","C"]}

# %%
Table
# Out:
# {'Name': ['Preeti', 'Abhi', nan, 'Aditi'],
#  'Marks': [78, 87, 95, 34],
#  'Grade': ['A', 'A', 'B', 'C']}

# %%
df=pd.DataFrame(Table)

# %%
df
# Out:
#      Name  Marks Grade
# 0  Preeti     78     A
# 1    Abhi     87     A
# 2     NaN     95     B
# 3   Aditi     34     C

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    3 non-null      object
#  1   Marks   4 non-null      int64
#  2   Grade   4 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 228.0+ bytes

# %%
df.describe()
# Out:
#            Marks
# count   4.000000
# mean   73.500000
# std    27.233558
# min    34.000000
# 25%    67.000000
# 50%    82.500000
# 75%    89.000000
# max    95.000000

# %%
df[(df["Marks"]<100) & (df["Marks"]>70)]
# Out:
#      Name  Marks Grade
# 0  Preeti     78     A
# 1    Abhi     87     A
# 2     NaN     95     B

# %%
fortune=pd.read_csv(r"C:\Users\Preeti\Desktop\Preeti\Christ\Excel files (python)\fortune1000.csv",index_col=0)

# %%
fortune
# Out:
#                          Company                        Sector  \
# Rank
# 1                        Walmart                     Retailing
# 2                    Exxon Mobil                        Energy
# 3                          Apple                    Technology
# 4             Berkshire Hathaway                    Financials
# 5                       McKesson                   Health Care
# ...                          ...                           ...
# 996   New York Community Bancorp                    Financials
# 997    Portland General Electric                        Energy
# 997    Portland General Electric                        Energy
# 999                      Wendy’s  Hotels, Resturants & Leisure
# 1000           Briggs & Stratton                   Industrials
#
#                                       Industry  Revenue  Profits  Employees
# Rank
# 1                        General Merchandisers   482130    14694    2300000
# ...

# %%
dt=pd.DataFrame(fortune)
dt
# Out:
#                          Company                        Sector  \
# Rank
# 1                        Walmart                     Retailing
# 2                    Exxon Mobil                        Energy
# 3                          Apple                    Technology
# 4             Berkshire Hathaway                    Financials
# 5                       McKesson                   Health Care
# ...                          ...                           ...
# 996   New York Community Bancorp                    Financials
# 997    Portland General Electric                        Energy
# 997    Portland General Electric                        Energy
# 999                      Wendy’s  Hotels, Resturants & Leisure
# 1000           Briggs & Stratton                   Industrials
#
#                                       Industry  Revenue  Profits  Employees
# Rank
# 1                        General Merchandisers   482130    14694    2300000
# ...

# %%
dt.groupby("Sector")["Profits"].mean()
# Out:
# Sector
# Aerospace & Defense             1437.100000
# Apparel                          549.066667
# Business Services                553.470588
# Chemicals                        754.266667
# Energy                          -602.024590
# Engineering & Construction       204.000000
# Financials                      1872.007194
# Food and Drug Stores            1117.266667
# Food, Beverages & Tobacco       1195.744186
# Health Care                     1414.853333
# Hotels, Resturants & Leisure     827.880000
# Household Products               515.285714
# Industrials                      451.391304
# Materials                        102.976744
# Media                            973.880000
# Motor Vehicles & Parts          1079.083333
# Retailing                        597.875000
# Technology                      1769.343137
# Telecommunications              3242.466667
# Transportation                  1226.916667
# Wholesalers                      205.825000
# ...

# %%
Sectors=fortune.groupby("Sector")

# %%
Sectors

# %%
len(Sectors)
# Out:
# 21

# %%
Sectors.size()
# Out:
# Sector
# Aerospace & Defense              20
# Apparel                          15
# Business Services                51
# Chemicals                        30
# Energy                          122
# Engineering & Construction       26
# Financials                      139
# Food and Drug Stores             15
# Food, Beverages & Tobacco        43
# Health Care                      75
# Hotels, Resturants & Leisure     25
# Household Products               28
# Industrials                      46
# Materials                        43
# Media                            25
# Motor Vehicles & Parts           24
# Retailing                        80
# Technology                      102
# Telecommunications               15
# Transportation                   36
# Wholesalers                      40
# dtype: int64

# %%
Sectors.first()
# Out:
#                                              Company  \
# Sector
# Aerospace & Defense                           Boeing
# Apparel                                         Nike
# Business Services                      ManpowerGroup
# Chemicals                               Dow Chemical
# Energy                                   Exxon Mobil
# Engineering & Construction                     Fluor
# Financials                        Berkshire Hathaway
# Food and Drug Stores                      CVS Health
# Food, Beverages & Tobacco     Archer Daniels Midland
# Health Care                                 McKesson
# Hotels, Resturants & Leisure              McDonald’s
# Household Products                  Procter & Gamble
# Industrials                         General Electric
# Materials                                      Alcoa
# Media                                         Disney
# Motor Vehicles & Parts                General Motors
# ...

# %%
Sectors.last()
# Out:
#                                                         Company  \
# Sector
# Aerospace & Defense                       Delta Tucker Holdings
# Apparel                                                   Guess
# Business Services                         DeVry Education Group
# Chemicals                                           H.B. Fuller
# Energy                                Portland General Electric
# Engineering & Construction                         MDC Holdings
# Financials                           New York Community Bancorp
# Food and Drug Stores                                     Fred’s
# Food, Beverages & Tobacco            Alliance One International
# Health Care                                  Providence Service
# Hotels, Resturants & Leisure                            Wendy’s
# Household Products                                       Revlon
# Industrials                                   Briggs & Stratton
# ...

# %%
Sectors.get_group("Financials")["Revenue"].sum()
# Out:
# np.int64(2217159)

# %%
Sectors.get_group("Energy")["Profits"].sum()
# Out:
# np.int64(-73447)

# %%
Sectors.get_group("Media")["Profits"].sum()
# Out:
# np.int64(24347)

# %%
fortune.groupby(["Industry","Sector"])["Profits"].sum()    # or we could directly group the columns we want from the data
# Out:
# Industry                                       Sector
# Advertising, marketing                         Business Services       1549
# Aerospace and Defense                          Aerospace & Defense    28742
# Airlines                                       Transportation         23800
# Apparel                                        Apparel                 8236
# Automotive Retailing, Services                 Retailing               2550
#                                                                       ...
# Waste Management                               Business Services       1718
# Wholesalers: Diversified                       Wholesalers             5193
# Wholesalers: Electronics and Office Equipment  Wholesalers             1857
# Wholesalers: Food and Grocery                  Wholesalers             1166
# Wholesalers: Health Care                       Health Care             3361
# Name: Profits, Length: 79, dtype: int64

# %%
dt.groupby(["Industry","Sector"])["Profits"].sum()    # cuz we have made a data frame for the fortune file
# Out:
# Industry                                       Sector
# Advertising, marketing                         Business Services       1549
# Aerospace and Defense                          Aerospace & Defense    28742
# Airlines                                       Transportation         23800
# Apparel                                        Apparel                 8236
# Automotive Retailing, Services                 Retailing               2550
#                                                                       ...
# Waste Management                               Business Services       1718
# Wholesalers: Diversified                       Wholesalers             5193
# Wholesalers: Electronics and Office Equipment  Wholesalers             1857
# Wholesalers: Food and Grocery                  Wholesalers             1166
# Wholesalers: Health Care                       Health Care             3361
# Name: Profits, Length: 79, dtype: int64

# %%
Sectors.get_group("Energy")
# Out:
#                         Company  Sector                      Industry  \
# Rank
# 2                   Exxon Mobil  Energy            Petroleum Refining
# 14                      Chevron  Energy            Petroleum Refining
# 30                  Phillips 66  Energy            Petroleum Refining
# 32                Valero Energy  Energy            Petroleum Refining
# 42           Marathon Petroleum  Energy            Petroleum Refining
# ...                         ...     ...                           ...
# 981                  WPX Energy  Energy  Mining, Crude-Oil Production
# 983    Adams Resources & Energy  Energy            Petroleum Refining
# 995                   EP Energy  Energy  Mining, Crude-Oil Production
# 997   Portland General Electric  Energy   Utilities: Gas and Electric
# 997   Portland General Electric  Energy   Utilities: Gas and Electric
#
#       Revenue  Profits  Employees
# Rank
# 2      246204    16150      75600
# 14     131118     4587      61500
# ...

# %%
Sectors["Revenue"].sum()
# Out:
# Sector
# Aerospace & Defense              357940
# Apparel                           95968
# Business Services                272195
# Chemicals                        243897
# Energy                          1517809
# Engineering & Construction       153983
# Financials                      2217159
# Food and Drug Stores             483769
# Food, Beverages & Tobacco        555967
# Health Care                     1614707
# Hotels, Resturants & Leisure     169546
# Household Products               234737
# Industrials                      497581
# Materials                        259145
# Media                            220764
# Motor Vehicles & Parts           482540
# Retailing                       1465076
# Technology                      1377600
# Telecommunications               461834
# Transportation                   408508
# Wholesalers                      444800
# Name: Revenue, dtype: int64

# %%
Sectors.agg({"Employees":"sum","Profits":"mean"})
# Out:
#                               Employees      Profits
# Sector
# Aerospace & Defense              968057  1437.100000
# Apparel                          346397   549.066667
# Business Services               1361050   553.470588
# Chemicals                        463651   754.266667
# Energy                          1188927  -602.024590
# Engineering & Construction       406708   204.000000
# Financials                      3359948  1872.007194
# Food and Drug Stores            1395398  1117.266667
# Food, Beverages & Tobacco       1211632  1195.744186
# Health Care                     2678289  1414.853333
# Hotels, Resturants & Leisure    2484245   827.880000
# Household Products               646038   515.285714
# Industrials                     1545229   451.391304
# Materials                        638123   102.976744
# Media                            550314   973.880000
# Motor Vehicles & Parts          1082560  1079.083333
# Retailing                       6227629   597.875000
# ...
