# %%
import pandas as pd

bond = pd.read_csv(r"C:\Users\Preeti\Desktop\Preeti\Christ\Excel files (python)\jamesbond.csv")
bond.head()
# Out:
#                     Film  Year         Actor       Director  Box Office  \
# 0                 Dr. No  1962  Sean Connery  Terence Young       448.8
# 1  From Russia with Love  1963  Sean Connery  Terence Young       543.8
# 2             Goldfinger  1964  Sean Connery   Guy Hamilton       820.4
# 3            Thunderball  1965  Sean Connery  Terence Young       848.1
# 4          Casino Royale  1967   David Niven     Ken Hughes       315.0
#
#    Budget  Bond Actor Salary
# 0     7.0                0.6
# 1    12.6                1.6
# 2    18.6                3.2
# 3    41.9                4.7
# 4    85.0                NaN

# %%
# Set Film as index
bond = bond.set_index("Film")
bond
# Out:
#                                  Year           Actor            Director  \
# Film
# Dr. No                           1962    Sean Connery       Terence Young
# From Russia with Love            1963    Sean Connery       Terence Young
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Thunderball                      1965    Sean Connery       Terence Young
# Casino Royale                    1967     David Niven          Ken Hughes
# You Only Live Twice              1967    Sean Connery       Lewis Gilbert
# On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# The Man with the Golden Gun      1974     Roger Moore        Guy Hamilton
# The Spy Who Loved Me             1977     Roger Moore       Lewis Gilbert
# Moonraker                        1979     Roger Moore       Lewis Gilbert
# ...

# %%
# Reset back to default integer index
bond = bond.reset_index()
bond
# Out:
#                                Film  Year           Actor            Director  \
# 0                            Dr. No  1962    Sean Connery       Terence Young
# 1             From Russia with Love  1963    Sean Connery       Terence Young
# 2                        Goldfinger  1964    Sean Connery        Guy Hamilton
# 3                       Thunderball  1965    Sean Connery       Terence Young
# 4                     Casino Royale  1967     David Niven          Ken Hughes
# 5               You Only Live Twice  1967    Sean Connery       Lewis Gilbert
# 6   On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# 7              Diamonds Are Forever  1971    Sean Connery        Guy Hamilton
# 8                  Live and Let Die  1973     Roger Moore        Guy Hamilton
# 9       The Man with the Golden Gun  1974     Roger Moore        Guy Hamilton
# 10             The Spy Who Loved Me  1977     Roger Moore       Lewis Gilbert
# ...

# %%
bond = bond.set_index(["Film", "Year"])
bond
# Out:
#                                                Actor            Director  \
# Film                            Year
# Dr. No                          1962    Sean Connery       Terence Young
# From Russia with Love           1963    Sean Connery       Terence Young
# Goldfinger                      1964    Sean Connery        Guy Hamilton
# Thunderball                     1965    Sean Connery       Terence Young
# Casino Royale                   1967     David Niven          Ken Hughes
# You Only Live Twice             1967    Sean Connery       Lewis Gilbert
# On Her Majesty's Secret Service 1969  George Lazenby       Peter R. Hunt
# Diamonds Are Forever            1971    Sean Connery        Guy Hamilton
# Live and Let Die                1973     Roger Moore        Guy Hamilton
# The Man with the Golden Gun     1974     Roger Moore        Guy Hamilton
# The Spy Who Loved Me            1977     Roger Moore       Lewis Gilbert
# ...

# %%
bond = bond.reset_index()
bond
# Out:
#                                Film  Year           Actor            Director  \
# 0                            Dr. No  1962    Sean Connery       Terence Young
# 1             From Russia with Love  1963    Sean Connery       Terence Young
# 2                        Goldfinger  1964    Sean Connery        Guy Hamilton
# 3                       Thunderball  1965    Sean Connery       Terence Young
# 4                     Casino Royale  1967     David Niven          Ken Hughes
# 5               You Only Live Twice  1967    Sean Connery       Lewis Gilbert
# 6   On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# 7              Diamonds Are Forever  1971    Sean Connery        Guy Hamilton
# 8                  Live and Let Die  1973     Roger Moore        Guy Hamilton
# 9       The Man with the Golden Gun  1974     Roger Moore        Guy Hamilton
# 10             The Spy Who Loved Me  1977     Roger Moore       Lewis Gilbert
# ...

# %%
# First row
bond.iloc[0]
bond
# Out:
#                                Film  Year           Actor            Director  \
# 0                            Dr. No  1962    Sean Connery       Terence Young
# 1             From Russia with Love  1963    Sean Connery       Terence Young
# 2                        Goldfinger  1964    Sean Connery        Guy Hamilton
# 3                       Thunderball  1965    Sean Connery       Terence Young
# 4                     Casino Royale  1967     David Niven          Ken Hughes
# 5               You Only Live Twice  1967    Sean Connery       Lewis Gilbert
# 6   On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# 7              Diamonds Are Forever  1971    Sean Connery        Guy Hamilton
# 8                  Live and Let Die  1973     Roger Moore        Guy Hamilton
# 9       The Man with the Golden Gun  1974     Roger Moore        Guy Hamilton
# 10             The Spy Who Loved Me  1977     Roger Moore       Lewis Gilbert
# ...

# %%
# First five rows
bond.iloc[0:5]
# Out:
#                     Film  Year         Actor       Director  Box Office  \
# 0                 Dr. No  1962  Sean Connery  Terence Young       448.8
# 1  From Russia with Love  1963  Sean Connery  Terence Young       543.8
# 2             Goldfinger  1964  Sean Connery   Guy Hamilton       820.4
# 3            Thunderball  1965  Sean Connery  Terence Young       848.1
# 4          Casino Royale  1967   David Niven     Ken Hughes       315.0
#
#    Budget  Bond Actor Salary
# 0     7.0                0.6
# 1    12.6                1.6
# 2    18.6                3.2
# 3    41.9                4.7
# 4    85.0                NaN

# %%
# Non‑contiguous rows
bond.iloc[[0, 3, 10]]
# Out:
#                     Film  Year         Actor       Director  Box Office  \
# 0                 Dr. No  1962  Sean Connery  Terence Young       448.8
# 3            Thunderball  1965  Sean Connery  Terence Young       848.1
# 10  The Spy Who Loved Me  1977   Roger Moore  Lewis Gilbert       533.0
#
#     Budget  Bond Actor Salary
# 0      7.0                0.6
# 3     41.9                4.7
# 10    45.1                NaN

# %%
# First row, first 3 columns
bond.iloc[0, 0:3]
# Out:
# Film           Dr. No
# Year             1962
# Actor    Sean Connery
# Name: 0, dtype: object

# %%
# First 3 rows, Year and Box Office columns (by position)
bond.iloc[0:3, [1, 4]]
# Out:
#                               Actor  Budget
# Film
# Dr. No                 Sean Connery     7.0
# From Russia with Love  Sean Connery    12.6
# Goldfinger             Sean Connery    18.6

# %%
# Single movie
bond.loc["Skyfall"]
# Out:
# Year                         2012
# Actor                Daniel Craig
# Director               Sam Mendes
# Box Office                  943.5
# Budget                      170.2
# Bond Actor Salary            14.5
# Name: Skyfall, dtype: object

# %%
# Multiple movies
bond.loc[["Skyfall", "Spectre"]]
# Out:
#          Year         Actor    Director  Box Office  Budget  Bond Actor Salary
# Film
# Skyfall  2012  Daniel Craig  Sam Mendes       943.5   170.2               14.5
# Spectre  2015  Daniel Craig  Sam Mendes       726.7   206.3               30.0

# %%
# Rows and specific columns
bond.loc["Skyfall", ["Year", "Actor", "Box Office"]]
# Out:
# Year                  2012
# Actor         Daniel Craig
# Box Office           943.5
# Name: Skyfall, dtype: object

# %%
# loc[row_labels, column_labels]
bond.loc["Skyfall", "Box Office"]
bond.loc[["Skyfall", "Spectre"], ["Year", "Box Office"]]
# Out:
#          Year  Box Office
# Film
# Skyfall  2012       943.5
# Spectre  2015       726.7

# %%
# iloc[row_positions, column_positions]
bond.iloc[0, 4]          # first row, Box Office
bond.iloc[0:3, [1, 4]]   # first 3 rows, Year & Box Office
# Out:
#                               Actor  Budget
# Film
# Dr. No                 Sean Connery     7.0
# From Russia with Love  Sean Connery    12.6
# Goldfinger             Sean Connery    18.6

# %%
# Change Skyfall budget
bond.loc["Skyfall", "Budget"] = 180.0
# By position
bond.iloc[0, 4] = 450.0    # change first row Box Office

# %%
# Replace all NaN salaries with 0
bond["Bond Actor Salary"] = bond["Bond Actor Salary"].fillna(0)
bond
# Out:
#                                  Year           Actor            Director  \
# Film
# Dr. No                           1962    Sean Connery       Terence Young
# From Russia with Love            1963    Sean Connery       Terence Young
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Thunderball                      1965    Sean Connery       Terence Young
# Casino Royale                    1967     David Niven          Ken Hughes
# You Only Live Twice              1967    Sean Connery       Lewis Gilbert
# On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# The Man with the Golden Gun      1974     Roger Moore        Guy Hamilton
# The Spy Who Loved Me             1977     Roger Moore       Lewis Gilbert
# Moonraker                        1979     Roger Moore       Lewis Gilbert
# ...

# %%
# Increase Daniel Craig salaries by 10
mask = bond["Actor"] == "Daniel Craig"
bond.loc[mask, "Bond Actor Salary"] = bond.loc[mask, "Bond Actor Salary"] + 10

# %%
# Rename specific columns
bond = bond.rename(columns={"Box Office": "BoxOffice", "Bond Actor Salary": "BondSalary"})

# %%
bond
# Out:
#                                  Year           Actor            Director  \
# Film
# Dr No                            1962    Sean Connery       Terence Young
# From Russia with Love            1963    Sean Connery       Terence Young
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Thunderball                      1965    Sean Connery       Terence Young
# Casino Royale                    1967     David Niven          Ken Hughes
# You Only Live Twice              1967    Sean Connery       Lewis Gilbert
# On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# The Man with the Golden Gun      1974     Roger Moore        Guy Hamilton
# The Spy Who Loved Me             1977     Roger Moore       Lewis Gilbert
# Moonraker                        1979     Roger Moore       Lewis Gilbert
# ...

# %%
# Rename index values (if Film is index)
bond = bond.rename(index={"Dr. No": "Dr No"})
bond
# Out:
#                                  Year           Actor            Director  \
# Film
# Dr No                            1962    Sean Connery       Terence Young
# From Russia with Love            1963    Sean Connery       Terence Young
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Thunderball                      1965    Sean Connery       Terence Young
# Casino Royale                    1967     David Niven          Ken Hughes
# You Only Live Twice              1967    Sean Connery       Lewis Gilbert
# On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# The Man with the Golden Gun      1974     Roger Moore        Guy Hamilton
# The Spy Who Loved Me             1977     Roger Moore       Lewis Gilbert
# Moonraker                        1979     Roger Moore       Lewis Gilbert
# ...

# %%
#replace all column names at once
bond.columns = ["Film", "Year", "Actor", "Director", "BoxOffice", "Budget", "BondSalary"]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[52], line 2
#       1 #replace all column names at once
# ----> 2 bond.columns = ["Film", "Year", "Actor", "Director", "BoxOffice", "Budget", "BondSalary"]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6313, in NDFrame.__setattr__(self, name, value)
#    6311 try:
#    6312     object.__getattribute__(self, name)
# -> 6313     return object.__setattr__(self, name, value)
#    6314 except AttributeError:
#    6315     pass
#
# File properties.pyx:69, in pandas._libs.properties.AxisProperty.__set__()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:814, in NDFrame._set_axis(self, axis, labels)
#     809 """
#     810 This is called from the cython code when we set the `index` attribute
#     811 directly, e.g. `series.index = [1, 2, 3]`.
#     812 """
#     813 labels = ensure_index(labels)
# ...

# %%
bond
# Out:
#                                  Year           Actor            Director  \
# Film
# Dr No                            1962    Sean Connery       Terence Young
# From Russia with Love            1963    Sean Connery       Terence Young
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Thunderball                      1965    Sean Connery       Terence Young
# Casino Royale                    1967     David Niven          Ken Hughes
# You Only Live Twice              1967    Sean Connery       Lewis Gilbert
# On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# The Man with the Golden Gun      1974     Roger Moore        Guy Hamilton
# The Spy Who Loved Me             1977     Roger Moore       Lewis Gilbert
# Moonraker                        1979     Roger Moore       Lewis Gilbert
# ...

# %%
# Drop columns
bond = bond.drop(columns=["BondSalary"])

# %%
bond
# Out:
#                                  Year           Actor            Director  \
# Film
# Dr No                            1962    Sean Connery       Terence Young
# From Russia with Love            1963    Sean Connery       Terence Young
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Thunderball                      1965    Sean Connery       Terence Young
# Casino Royale                    1967     David Niven          Ken Hughes
# You Only Live Twice              1967    Sean Connery       Lewis Gilbert
# On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# The Man with the Golden Gun      1974     Roger Moore        Guy Hamilton
# The Spy Who Loved Me             1977     Roger Moore       Lewis Gilbert
# Moonraker                        1979     Roger Moore       Lewis Gilbert
# ...

# %%
# Drop rows by index label
bond = bond.drop(index=["Skyfall"])

# %%
bond
# Out:
#                                  Year           Actor            Director  \
# Film
# Dr No                            1962    Sean Connery       Terence Young
# From Russia with Love            1963    Sean Connery       Terence Young
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Thunderball                      1965    Sean Connery       Terence Young
# Casino Royale                    1967     David Niven          Ken Hughes
# You Only Live Twice              1967    Sean Connery       Lewis Gilbert
# On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# The Man with the Golden Gun      1974     Roger Moore        Guy Hamilton
# The Spy Who Loved Me             1977     Roger Moore       Lewis Gilbert
# Moonraker                        1979     Roger Moore       Lewis Gilbert
# ...

# %%
# Drop rows by position
bond = bond.drop(index=bond.index[0:3])
bond
# Out:
#                                  Year           Actor            Director  \
# Film
# Thunderball                      1965    Sean Connery       Terence Young
# Casino Royale                    1967     David Niven          Ken Hughes
# You Only Live Twice              1967    Sean Connery       Lewis Gilbert
# On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# The Man with the Golden Gun      1974     Roger Moore        Guy Hamilton
# The Spy Who Loved Me             1977     Roger Moore       Lewis Gilbert
# Moonraker                        1979     Roger Moore       Lewis Gilbert
# For Your Eyes Only               1981     Roger Moore           John Glen
# Never Say Never Again            1983    Sean Connery      Irvin Kershner
# Octopussy                        1983     Roger Moore           John Glen
# ...

# %%
# 3 highest box office films
bond.nlargest(3, "BoxOffice")
# Out:
#                 Year         Actor            Director  BoxOffice  Budget
# Film
# Thunderball     1965  Sean Connery       Terence Young      848.1    41.9
# No Time to Die  2021  Daniel Craig  Cary Joji Fukunaga      774.2   301.0
# Spectre         2015  Daniel Craig          Sam Mendes      726.7   206.3

# %%
# 5 smallest budgets
bond.nsmallest(5, "Budget")
# Out:
#                                  Year           Actor       Director  \
# Film
# The Man with the Golden Gun      1974     Roger Moore   Guy Hamilton
# Live and Let Die                 1973     Roger Moore   Guy Hamilton
# Diamonds Are Forever             1971    Sean Connery   Guy Hamilton
# On Her Majesty's Secret Service  1969  George Lazenby  Peter R. Hunt
# Thunderball                      1965    Sean Connery  Terence Young
#
#                                  BoxOffice  Budget
# Film
# The Man with the Golden Gun          334.0    27.7
# Live and Let Die                     460.3    30.8
# Diamonds Are Forever                 442.5    34.7
# On Her Majesty's Secret Service      291.5    37.3
# Thunderball                          848.1    41.9

# %%
# Keep only films after 2000, others become NaN
after_2000 = bond.where(bond["Year"] > 2000)
after_2000
# Out:
#                                    Year           Actor            Director  \
# Film
# Thunderball                         NaN             NaN                 NaN
# Casino Royale                       NaN             NaN                 NaN
# You Only Live Twice                 NaN             NaN                 NaN
# On Her Majesty's Secret Service     NaN             NaN                 NaN
# Diamonds Are Forever                NaN             NaN                 NaN
# Live and Let Die                    NaN             NaN                 NaN
# The Man with the Golden Gun         NaN             NaN                 NaN
# The Spy Who Loved Me                NaN             NaN                 NaN
# Moonraker                           NaN             NaN                 NaN
# For Your Eyes Only                  NaN             NaN                 NaN
# Never Say Never Again               NaN             NaN                 NaN
# ...

# %%
# Standard boolean filtering (dropping rows that do not match)
only_craig = bond[bond["Actor"] == "Daniel Craig"]
only_craig
# Out:
#                    Year         Actor            Director  BoxOffice  Budget
# Film
# Casino Royale      2006  Daniel Craig     Martin Campbell      581.5   145.3
# Quantum of Solace  2008  Daniel Craig        Marc Forster      514.2   181.4
# Spectre            2015  Daniel Craig          Sam Mendes      726.7   206.3
# No Time to Die     2021  Daniel Craig  Cary Joji Fukunaga      774.2   301.0

# %%
# Example: profit = Box Office - Budget
def profit(row):
    return row["BoxOffice"] - row["Budget"]

bond["Profit"] = bond.apply(profit, axis="columns")
bond
# Out:
#                                  Year           Actor            Director  \
# Film
# Thunderball                      1965    Sean Connery       Terence Young
# Casino Royale                    1967     David Niven          Ken Hughes
# You Only Live Twice              1967    Sean Connery       Lewis Gilbert
# On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# The Man with the Golden Gun      1974     Roger Moore        Guy Hamilton
# The Spy Who Loved Me             1977     Roger Moore       Lewis Gilbert
# Moonraker                        1979     Roger Moore       Lewis Gilbert
# For Your Eyes Only               1981     Roger Moore           John Glen
# Never Say Never Again            1983    Sean Connery      Irvin Kershner
# Octopussy                        1983     Roger Moore           John Glen
# ...
