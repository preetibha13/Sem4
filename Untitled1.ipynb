# %%
import pandas as pd

# %%
import numpy as np

# %%
food=pd.read_csv(r"C:\Users\Preeti\OneDrive\Desktop\Preeti\Christ\Excel files (python)\restaurant_foods.csv")
food
# Out:
#    Food ID   Food Item  Price
# 0        1       Sushi   3.99
# 1        2     Burrito   9.99
# 2        3        Taco   2.99
# 3        4  Quesadilla   4.25
# 4        5       Pizza   2.49
# 5        6       Pasta  13.99
# 6        7       Steak  24.99
# 7        8       Salad  11.25
# 8        9       Donut   0.99
# 9       10       Drink   1.75

# %%
week1=pd.read_csv(r"C:\Users\Preeti\OneDrive\Desktop\Preeti\Christ\Excel files (python)\restaurant_week_1_sales.csv")
week1
# Out:
#      Customer ID  Food ID
# 0            537        9
# 1             97        4
# 2            658        1
# 3            202        2
# 4            155        9
# ..           ...      ...
# 245          413        9
# 246          926        6
# 247          134        3
# 248          396        6
# 249          535       10
#
# [250 rows x 2 columns]

# %%
time=pd.read_csv(r"C:\Users\Preeti\OneDrive\Desktop\Preeti\Christ\Excel files (python)\restaurant_week_1_times.csv")
time
# Out:
#     Time of Day
# 0      14:54:59
# 1      20:55:17
# 2      01:16:22
# 3      16:17:26
# 4      19:26:11
# ..          ...
# 245    04:44:14
# 246    07:46:21
# 247    20:45:08
# 248    01:09:06
# 249    18:18:50
#
# [250 rows x 1 columns]

# %%
week2=pd.read_csv(r"C:\Users\Preeti\OneDrive\Desktop\Preeti\Christ\Excel files (python)\restaurant_week_2_sales.csv")
week2
# Out:
#      Customer ID  Food ID
# 0            688       10
# 1            813        7
# 2            495       10
# 3            189        5
# 4            267        3
# ..           ...      ...
# 245          783       10
# 246          556       10
# 247          547        9
# 248          252        9
# 249          249        6
#
# [250 rows x 2 columns]

# %%
week1.head()
# Out:
#    Customer ID  Food ID
# 0          537        9
# 1           97        4
# 2          658        1
# 3          202        2
# 4          155        9

# %%
week2.head()
# Out:
#    Customer ID  Food ID
# 0          688       10
# 1          813        7
# 2          495       10
# 3          189        5
# 4          267        3

# %%
len(week1)
# Out:
# 250

# %%
len(week2)
# Out:
# 250

# %%
pd.concat([week1,week2])
# Out:
#      Customer ID  Food ID
# 0            537        9
# 1             97        4
# 2            658        1
# 3            202        2
# 4            155        9
# ..           ...      ...
# 245          783       10
# 246          556       10
# 247          547        9
# 248          252        9
# 249          249        6
#
# [500 rows x 2 columns]

# %%
pd.concat([week1,week2],ignore_index=False)
# Out:
#      Customer ID  Food ID
# 0            537        9
# 1             97        4
# 2            658        1
# 3            202        2
# 4            155        9
# ..           ...      ...
# 245          783       10
# 246          556       10
# 247          547        9
# 248          252        9
# 249          249        6
#
# [500 rows x 2 columns]

# %%
pd.concat([week1,week2],ignore_index=True)
# Out:
#      Customer ID  Food ID
# 0            537        9
# 1             97        4
# 2            658        1
# 3            202        2
# 4            155        9
# ..           ...      ...
# 495          783       10
# 496          556       10
# 497          547        9
# 498          252        9
# 499          249        6
#
# [500 rows x 2 columns]

# %%
pd.concat([week1,week2],keys=["week1","week2"]).sort_index()
# Out:
#            Customer ID  Food ID
# week1 0            537        9
#       1             97        4
#       2            658        1
#       3            202        2
#       4            155        9
# ...                ...      ...
# week2 245          783       10
#       246          556       10
#       247          547        9
#       248          252        9
#       249          249        6
#
# [500 rows x 2 columns]

# %%
df1=pd.DataFrame([1,2,3],columns=["A"])
df1
# Out:
#    A
# 0  1
# 1  2
# 2  3

# %%
df2=pd.DataFrame([4,5,6],columns=["B"])
df2
# Out:
#    B
# 0  4
# 1  5
# 2  6

# %%
pd.concat([df1,df2])
# Out:
#      A    B
# 0  1.0  NaN
# 1  2.0  NaN
# 2  3.0  NaN
# 0  NaN  4.0
# 1  NaN  5.0
# 2  NaN  6.0

# %%
pd.concat([df1,df2],axis="index")
# Out:
#      A    B
# 0  1.0  NaN
# 1  2.0  NaN
# 2  3.0  NaN
# 0  NaN  4.0
# 1  NaN  5.0
# 2  NaN  6.0

# %%
pd.concat([df1,df2],axis="columns")
# Out:
#    A  B
# 0  1  4
# 1  2  5
# 2  3  6

# %%
week1.merge(food, how="left",on="Food ID")   # mergerd according to the left table thats why its called left merge
# Out:
#      Customer ID  Food ID   Food Item  Price
# 0            537        9       Donut   0.99
# 1             97        4  Quesadilla   4.25
# 2            658        1       Sushi   3.99
# 3            202        2     Burrito   9.99
# 4            155        9       Donut   0.99
# ..           ...      ...         ...    ...
# 245          413        9       Donut   0.99
# 246          926        6       Pasta  13.99
# 247          134        3        Taco   2.99
# 248          396        6       Pasta  13.99
# 249          535       10       Drink   1.75
#
# [250 rows x 4 columns]

# %%
week2.merge(customers,how="left",left_on="Customer ID",right_on="ID")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 week2.merge(customers,how="left",left_on="Customer ID",right_on="ID")
#
# NameError: name 'week2' is not defined

# %%
# exporatory Data analysis is everything we have done till now (merge, data cleaning etc)
