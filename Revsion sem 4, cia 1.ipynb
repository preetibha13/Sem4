# %%
import pandas as pd

# %%
import numpy as np

# %%
nba=pd.read_csv(r"C:\Users\Preeti\Desktop\Preeti\Christ\Excel files (python)\nba.csv")
nba
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
# 591                NaN                 NaN      NaN    NaN     NaN
#
#            College      Salary
# 0        Villanova   4556983.0
# 1       Fenerbahce  18700000.0
# 2         Michigan   4094244.0
# 3      Elan Chalon  20616000.0
# ...

# %%
nba.dropna() #drops all bad rows
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 585     Eugene Omoruyi  Washington Wizards        F    6-6   235.0
# 586       Jordan Poole  Washington Wizards        G    6-4   194.0
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
#
#            College      Salary
# 0        Villanova   4556983.0
# 1       Fenerbahce  18700000.0
# 2         Michigan   4094244.0
# 3      Elan Chalon  20616000.0
# ...

# %%
nba.dropna(how="all") # when all values in the row are na
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 586       Jordan Poole  Washington Wizards        G    6-4   194.0
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
#
#            College      Salary
# 0        Villanova   4556983.0
# 1       Fenerbahce  18700000.0
# 2         Michigan   4094244.0
# 3      Elan Chalon  20616000.0
# ...

# %%
nba.dropna(subset=["College"]) # drops na value specifically inn the given subset like college or salary
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 586       Jordan Poole  Washington Wizards        G    6-4   194.0
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
#
#            College      Salary
# 0        Villanova   4556983.0
# 1       Fenerbahce  18700000.0
# 2         Michigan   4094244.0
# 3      Elan Chalon  20616000.0
# ...

# %%
nba.dropna(subset=["College"])
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 586       Jordan Poole  Washington Wizards        G    6-4   194.0
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
#
#            College      Salary
# 0        Villanova   4556983.0
# 1       Fenerbahce  18700000.0
# 2         Michigan   4094244.0
# 3      Elan Chalon  20616000.0
# ...

# %%
nba.dropna(subset=["College","Salary"])
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 585     Eugene Omoruyi  Washington Wizards        F    6-6   235.0
# 586       Jordan Poole  Washington Wizards        G    6-4   194.0
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
#
#            College      Salary
# 0        Villanova   4556983.0
# 1       Fenerbahce  18700000.0
# 2         Michigan   4094244.0
# 3      Elan Chalon  20616000.0
# ...

# %%
nba.dropna(subset="College")
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 586       Jordan Poole  Washington Wizards        G    6-4   194.0
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
#
#            College      Salary
# 0        Villanova   4556983.0
# 1       Fenerbahce  18700000.0
# 2         Michigan   4094244.0
# 3      Elan Chalon  20616000.0
# ...

# %%
nba.dropna(subset="Salary")
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 585     Eugene Omoruyi  Washington Wizards        F    6-6   235.0
# 586       Jordan Poole  Washington Wizards        G    6-4   194.0
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
#
#            College      Salary
# 0        Villanova   4556983.0
# 1       Fenerbahce  18700000.0
# 2         Michigan   4094244.0
# 3      Elan Chalon  20616000.0
# ...

# %%
nba.info()  # col name, null/non null, data type
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 592 entries, 0 to 591
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      591 non-null    object
#  1   Team      591 non-null    object
#  2   Position  584 non-null    object
#  3   Height    585 non-null    object
#  4   Weight    584 non-null    float64
#  5   College   578 non-null    object
#  6   Salary    488 non-null    float64
# dtypes: float64(2), object(5)
# memory usage: 32.5+ KB

# %%
nba.describe()  # mathematical operations
# Out:
#            Weight        Salary
# count  584.000000  4.880000e+02
# mean   214.763699  9.218978e+06
# std     23.460612  1.131927e+07
# min    160.000000  5.088910e+05
# 25%    198.000000  1.980599e+06
# 50%    215.000000  4.018638e+06
# 75%    230.000000  1.169694e+07
# max    290.000000  5.191562e+07

# %%
nba.fillna(0) # fills na places with zero everywhere
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
# 591                  0                   0        0      0     0.0
#
#            College      Salary
# 0        Villanova   4556983.0
# 1       Fenerbahce  18700000.0
# 2         Michigan   4094244.0
# 3      Elan Chalon  20616000.0
# ...

# %%
nba.Salary=nba.Salary.fillna(0)
nba.Salary
# Out:
# 0       4556983.0
# 1      18700000.0
# 2       4094244.0
# 3      20616000.0
# 4       2581522.0
#           ...
# 587     1719864.0
# 588    10250000.0
# 589           0.0
# 590     8195122.0
# 591           0.0
# Name: Salary, Length: 592, dtype: float64

# %%
nba # there hasnt been any permanenet change
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
# 591                NaN                 NaN      NaN    NaN     NaN
#
#            College      Salary
# 0        Villanova   4556983.0
# 1       Fenerbahce  18700000.0
# 2         Michigan   4094244.0
# 3      Elan Chalon  20616000.0
# ...

# %%
nba.College=nba.College.fillna("Unknown")
nba.College
# Out:
# 0          Villanova
# 1         Fenerbahce
# 2           Michigan
# 3        Elan Chalon
# 4           Maryland
#            ...
# 587           Toledo
# 588    Wichita State
# 589      Real Madrid
# 590             Utah
# 591          Unknown
# Name: College, Length: 592, dtype: object

# %%
nba.loc[:,["Name","Team","Position"]].head(5) #: means go through the file, this is filtering of data
# Out:
#                 Name           Team Position
# 0         Saddiq Bey  Atlanta Hawks        F
# 1  Bogdan Bogdanovic  Atlanta Hawks        G
# 2        Kobe Bufkin  Atlanta Hawks        G
# 3       Clint Capela  Atlanta Hawks        C
# 4     Bruno Fernando  Atlanta Hawks      F-C

# %%
nba.loc[:,["Name","College","Salary","Position"]].head(10)
# Out:
#                 Name           College      Salary Position
# 0         Saddiq Bey         Villanova   4556983.0        F
# 1  Bogdan Bogdanovic        Fenerbahce  18700000.0        G
# 2        Kobe Bufkin          Michigan   4094244.0        G
# 3       Clint Capela       Elan Chalon  20616000.0        C
# 4     Bruno Fernando          Maryland   2581522.0      F-C
# 5      Trent Forrest     Florida State    508891.0        G
# 6         AJ Griffin              Duke   3712920.0        F
# 7     Mouhamed Gueye  Washington State   1119563.0        F
# 8    De'Andre Hunter          Virginia  20089286.0      F-G
# 9      Jalen Johnson              Duke   2925360.0        F

# %%
nba.loc[:,["Name","Position","Salary"]].head()
# Out:
#                 Name Position      Salary
# 0         Saddiq Bey        F   4556983.0
# 1  Bogdan Bogdanovic        G  18700000.0
# 2        Kobe Bufkin        G   4094244.0
# 3       Clint Capela        C  20616000.0
# 4     Bruno Fernando      F-C   2581522.0

# %%
nba.loc[nba["Position"]=="G",["Name"]].head()
# Out:
#                  Name
# 1   Bogdan Bogdanovic
# 2         Kobe Bufkin
# 5       Trent Forrest
# 10         Seth Lundy
# 11   Garrison Mathews

# %%
nba.loc[nba["Position"]=="G",["Name","College","Position"]].head() # filters position with only G
# Out:
#                  Name        College Position
# 1   Bogdan Bogdanovic     Fenerbahce        G
# 2         Kobe Bufkin       Michigan        G
# 5       Trent Forrest  Florida State        G
# 10         Seth Lundy     Penn State        G
# 11   Garrison Mathews       Lipscomb        G

# %%
nba.loc[nba["Position"]=="F",["Name","College","Position"]].head() # head just shows the first 5 rows with our condition
# Out:
#               Name           College Position
# 0       Saddiq Bey         Villanova        F
# 6       AJ Griffin              Duke        F
# 7   Mouhamed Gueye  Washington State        F
# 9    Jalen Johnson              Duke        F
# 18   Dalano Banton          Nebraska        F

# %%
nba.loc[nba["Position"]=="C",["Name","College","Position"]].head()
# Out:
#                  Name         College Position
# 3        Clint Capela     Elan Chalon        C
# 26  Mfiondu Kabengele   Florida State        C
# 39        Nic Claxton         Georgia        C
# 45     Day'Ron Sharpe  North Carolina        C
# 67      Nick Richards        Kentucky        C

# %%
nba["Salary_in"]=nba["Salary"]*1.05  # broadcasting function, math operations 
nba["Salary_in"]
# Out:
# 0       4784832.15
# 1      19635000.00
# 2       4298956.20
# 3      21646800.00
# 4       2710598.10
#           ...
# 587     1805857.20
# 588    10762500.00
# 589           0.00
# 590     8604878.10
# 591           0.00
# Name: Salary_in, Length: 592, dtype: float64

# %%
nba["Salary"]=nba["Salary"]*2
nba["Salary"]
# Out:
# 0       9113966.0
# 1      37400000.0
# 2       8188488.0
# 3      41232000.0
# 4       5163044.0
#           ...
# 587     3439728.0
# 588    20500000.0
# 589           0.0
# 590    16390244.0
# 591           0.0
# Name: Salary, Length: 592, dtype: float64

# %%
nba # still no change in the actual data
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
# 591                NaN                 NaN      NaN    NaN     NaN
#
#            College      Salary    Salary_in
# 0        Villanova   9113966.0   4784832.15
# 1       Fenerbahce  37400000.0  19635000.00
# ...

# %%
#dataframe

# %%
Table={"Name":["Teisya",np.nan,"Rain",np.nan,"Power"],"Register":[1,2,3,4,5],"Class":["A",np.nan,"B","C","D"],"Score":[45,67,89,98,74]} # np.nan gives us NaN in the data

# %%
data_frame=pd.DataFrame(Table)
data_frame
# Out:
#      Name  Register Class  Score
# 0  Teisya         1     A     45
# 1     NaN         2   NaN     67
# 2    Rain         3     B     89
# 3     NaN         4     C     98
# 4   Power         5     D     74

# %%
data={"Friuts":["banana","Apple","Grapes"],"kgs":[2,4,1]}
dt=pd.DataFrame(data)

# %%
dt
# Out:
#    Friuts  kgs
# 0  banana    2
# 1   Apple    4
# 2  Grapes    1

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Friuts  3 non-null      object
#  1   kgs     3 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 180.0+ bytes

# %%
nba.iloc[:10,3]  #iloc is index
# Out:
# 0     6-7
# 1     6-5
# 2     6-5
# 3    6-10
# 4    6-10
# 5     6-4
# 6     6-6
# 7    6-11
# 8     6-8
# 9     6-8
# Name: Height, dtype: object

# %%
nba.iloc

# %%
nba.iloc[:10,3]
nba.iloc

# %%
nba[(nba["Salary"]>4000000) & (nba["Salary"]<5000000)]
# Out:
#                        Name                    Team Position Height  Weight  \
# 18            Dalano Banton          Boston Celtics        F    6-7   204.0
# 19           Oshae Brissett          Boston Celtics      F-G    6-7   210.0
# 27              Luke Kornet          Boston Celtics      C-F    7-2   250.0
# 36            Darius Bazley           Brooklyn Nets        F    6-9   216.0
# 45           Day'Ron Sharpe           Brooklyn Nets        C    6-9   265.0
# 48               Cam Thomas           Brooklyn Nets        G    6-3   210.0
# 50          Trendon Watford           Brooklyn Nets        F    6-8   237.0
# 87             Terry Taylor           Chicago Bulls        F    6-4   230.0
# 97                Ty Jerome     Cleveland Cavaliers      G-F    6-5   195.0
# 130            Joe Wieskamp        Dallas Mavericks      G-F    6-6   205.0
# 137           Vlatko Cancar          Denver Nuggets        F    6-8   236.0
# ...

# %%
nba[(nba["Salary"]>3000000) & (nba["Salary"]<4500000)]
# Out:
#                  Name                Team Position Height  Weight  \
# 11   Garrison Mathews       Atlanta Hawks        G    6-6   215.0
# 18      Dalano Banton      Boston Celtics        F    6-7   204.0
# 19     Oshae Brissett      Boston Celtics      F-G    6-7   210.0
# 24         Sam Hauser      Boston Celtics        F    6-7   217.0
# 36      Darius Bazley       Brooklyn Nets        F    6-9   216.0
# ..                ...                 ...      ...    ...     ...
# 561    Romeo Langford           Utah Jazz      G-F    6-5   216.0
# 566      Luka Samanic           Utah Jazz        F   6-10   227.0
# 573      Xavier Cooks  Washington Wizards        F    6-8   183.0
# 579      Anthony Gill  Washington Wizards        F    6-8   230.0
# 587      Ryan Rollins  Washington Wizards        G    6-3   180.0
#
#                College     Salary   Salary_in
# 11            Lipscomb  4000000.0  2100000.00
# 18            Nebraska  4039412.0  2120691.30
# ...

# %%
nba[(nba["Salary"]>4500000000) & (nba["Salary"])<5000000000]
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
# 591                NaN                 NaN      NaN    NaN     NaN
#
#            College      Salary    Salary_in
# 0        Villanova   9113966.0   4784832.15
# 1       Fenerbahce  37400000.0  19635000.00
# ...

# %%
fortune=pd.read_csv(r"C:\Users\Preeti\Desktop\Preeti\Christ\Excel files (python)\fortune1000.csv",index_col="Rank")
fortune
# Out:
#                          Company                        Sector  \
# Rank
# 1                        Walmart                     Retailing
# 2                    Exxon Mobil                        Energy
# 3                          Apple                    Technology
# 4             Berkshire Hathaway                    Financials
# 5                       McKesson                   Health Care
# ...                          ...                           ...
# 996   New York Community Bancorp                    Financials
# 997    Portland General Electric                        Energy
# 997    Portland General Electric                        Energy
# 999                      Wendy’s  Hotels, Resturants & Leisure
# 1000           Briggs & Stratton                   Industrials
#
#                                       Industry  Revenue  Profits  Employees
# Rank
# 1                        General Merchandisers   482130    14694    2300000
# ...

# %%
df=pd.DataFrame(fortune)

# %%
df.groupby("Sector")["Profits"].sum()
# Out:
# Sector
# Aerospace & Defense              28742
# Apparel                           8236
# Business Services                28227
# Chemicals                        22628
# Energy                          -73447
# Engineering & Construction        5304
# Financials                      260209
# Food and Drug Stores             16759
# Food, Beverages & Tobacco        51417
# Health Care                     106114
# Hotels, Resturants & Leisure     20697
# Household Products               14428
# Industrials                      20764
# Materials                         4428
# Media                            24347
# Motor Vehicles & Parts           25898
# Retailing                        47830
# Technology                      180473
# Telecommunications               48637
# Transportation                   44169
# Wholesalers                       8233
# Name: Profits, dtype: int64

# %%
df.groupby(["Industry","Sector"])["Profits"].mean()
# Out:
# Industry                                       Sector
# Advertising, marketing                         Business Services       774.500000
# Aerospace and Defense                          Aerospace & Defense    1437.100000
# Airlines                                       Transportation         2644.444444
# Apparel                                        Apparel                 549.066667
# Automotive Retailing, Services                 Retailing               255.000000
#                                                                          ...
# Waste Management                               Business Services       343.600000
# Wholesalers: Diversified                       Wholesalers             207.720000
# Wholesalers: Electronics and Office Equipment  Wholesalers             232.125000
# Wholesalers: Food and Grocery                  Wholesalers             194.333333
# Wholesalers: Health Care                       Health Care             560.166667
# ...

# %%
df.groupby("Industry")["Profits"].sum()
# Out:
# Industry
# Advertising, marketing                            1549
# Aerospace and Defense                            28742
# Airlines                                         23800
# Apparel                                           8236
# Automotive Retailing, Services                    2550
#                                                  ...
# Waste Management                                  1718
# Wholesalers: Diversified                          5193
# Wholesalers: Electronics and Office Equipment     1857
# Wholesalers: Food and Grocery                     1166
# Wholesalers: Health Care                          3361
# Name: Profits, Length: 73, dtype: int64

# %%
Group_sector=fortune.groupby("Sector")  #alternative to groupby : IMP

# %%
Group_sector

# %%
len(Group_sector) # total number of sectors
# Out:
# 21

# %%
Group_sector.size()  # for that sector how many companies are there
# Out:
# Sector
# Aerospace & Defense              20
# Apparel                          15
# Business Services                51
# Chemicals                        30
# Energy                          122
# Engineering & Construction       26
# Financials                      139
# Food and Drug Stores             15
# Food, Beverages & Tobacco        43
# Health Care                      75
# Hotels, Resturants & Leisure     25
# Household Products               28
# Industrials                      46
# Materials                        43
# Media                            25
# Motor Vehicles & Parts           24
# Retailing                        80
# Technology                      102
# Telecommunications               15
# Transportation                   36
# Wholesalers                      40
# dtype: int64

# %%
Group_sector.first()  #1st half of the data
# Out:
#                                              Company  \
# Sector
# Aerospace & Defense                           Boeing
# Apparel                                         Nike
# Business Services                      ManpowerGroup
# Chemicals                               Dow Chemical
# Energy                                   Exxon Mobil
# Engineering & Construction                     Fluor
# Financials                        Berkshire Hathaway
# Food and Drug Stores                      CVS Health
# Food, Beverages & Tobacco     Archer Daniels Midland
# Health Care                                 McKesson
# Hotels, Resturants & Leisure              McDonald’s
# Household Products                  Procter & Gamble
# Industrials                         General Electric
# Materials                                      Alcoa
# Media                                         Disney
# Motor Vehicles & Parts                General Motors
# ...

# %%
Group_sector.last()  # 2nd half of the data
# Out:
#                                                         Company  \
# Sector
# Aerospace & Defense                       Delta Tucker Holdings
# Apparel                                                   Guess
# Business Services                         DeVry Education Group
# Chemicals                                           H.B. Fuller
# Energy                                Portland General Electric
# Engineering & Construction                         MDC Holdings
# Financials                           New York Community Bancorp
# Food and Drug Stores                                     Fred’s
# Food, Beverages & Tobacco            Alliance One International
# Health Care                                  Providence Service
# Hotels, Resturants & Leisure                            Wendy’s
# Household Products                                       Revlon
# Industrials                                   Briggs & Stratton
# ...

# %%
# nested loop

# %%
#get_group is a function - Its a loop

# %%
Group_sector.get_group("Energy")["Profits"].sum()
# Out:
# np.int64(-73447)

# %%
Group_sector.get_group("Apparel")["Profits"].sum()
# Out:
# np.int64(8236)

# %%
fortune.groupby("Industry")["Profits"].sum()
# Out:
# Industry
# Advertising, marketing                            1549
# Aerospace and Defense                            28742
# Airlines                                         23800
# Apparel                                           8236
# Automotive Retailing, Services                    2550
#                                                  ...
# Waste Management                                  1718
# Wholesalers: Diversified                          5193
# Wholesalers: Electronics and Office Equipment     1857
# Wholesalers: Food and Grocery                     1166
# Wholesalers: Health Care                          3361
# Name: Profits, Length: 73, dtype: int64

# %%
fortune.groupby(["Sector","Industry"])["Profits"].sum()
# Out:
# Sector               Industry
# Aerospace & Defense  Aerospace and Defense                            28742
# Apparel              Apparel                                           8236
# Business Services    Advertising, marketing                            1549
#                      Diversified Outsourcing Services                  4305
#                      Education                                           69
#                                                                       ...
# Transportation       Trucking, Truck Leasing                           1910
# Wholesalers          Miscellaneous                                       17
#                      Wholesalers: Diversified                          5193
#                      Wholesalers: Electronics and Office Equipment     1857
#                      Wholesalers: Food and Grocery                     1166
# Name: Profits, Length: 79, dtype: int64

# %%
Group_sector.get_group("Energy") # groups all data of sector energy
# Out:
#                         Company  Sector                      Industry  \
# Rank
# 2                   Exxon Mobil  Energy            Petroleum Refining
# 14                      Chevron  Energy            Petroleum Refining
# 30                  Phillips 66  Energy            Petroleum Refining
# 32                Valero Energy  Energy            Petroleum Refining
# 42           Marathon Petroleum  Energy            Petroleum Refining
# ...                         ...     ...                           ...
# 981                  WPX Energy  Energy  Mining, Crude-Oil Production
# 983    Adams Resources & Energy  Energy            Petroleum Refining
# 995                   EP Energy  Energy  Mining, Crude-Oil Production
# 997   Portland General Electric  Energy   Utilities: Gas and Electric
# 997   Portland General Electric  Energy   Utilities: Gas and Electric
#
#       Revenue  Profits  Employees
# Rank
# 2      246204    16150      75600
# 14     131118     4587      61500
# ...

# %%
Group_sector.get_group("Apparel")
# Out:
#                    Company   Sector Industry  Revenue  Profits  Employees
# Rank
# 91                    Nike  Apparel  Apparel    30601     3273      62600
# 231                     VF  Apparel  Apparel    12377     1232      64000
# 340                    PVH  Apparel  Apparel     8020      572      26200
# 354           Ralph Lauren  Apparel  Apparel     7620      702      20000
# 448            Hanesbrands  Apparel  Apparel     5732      429      65300
# 547           Levi Strauss  Apparel  Apparel     4495      209      12500
# 575                  Coach  Apparel  Apparel     4192      402      12950
# 597           Under Armour  Apparel  Apparel     3963      233       9600
# 683           Fossil Group  Apparel  Apparel     3229      221      15100
# 695        Skechers U.S.A.  Apparel  Apparel     3159      232       6400
# 726               Carter’s  Apparel  Apparel     3014      238      16800
# 794   Wolverine World Wide  Apparel  Apparel     2692      123       6550
# ...

# %%
Group_sector.get_group("Apparel")["Profits"].sum()
# Out:
# np.int64(8236)

# %%
Group_sector["Revenue"].sum() # sum of revenue for every sector
# Out:
# Sector
# Aerospace & Defense              357940
# Apparel                           95968
# Business Services                272195
# Chemicals                        243897
# Energy                          1517809
# Engineering & Construction       153983
# Financials                      2217159
# Food and Drug Stores             483769
# Food, Beverages & Tobacco        555967
# Health Care                     1614707
# Hotels, Resturants & Leisure     169546
# Household Products               234737
# Industrials                      497581
# Materials                        259145
# Media                            220764
# Motor Vehicles & Parts           482540
# Retailing                       1465076
# Technology                      1377600
# Telecommunications               461834
# Transportation                   408508
# Wholesalers                      444800
# Name: Revenue, dtype: int64

# %%
#Sector & Industry size

# %%
Group_sector.agg({"Employees":"sum","Profits":"mean","Revenue":"sum"}) # always use small s , m for sum and mean functions 
# the agg computes multiple statistics for one or more columns simultaneously, making it particularly useful for summarizing data in a DataFrame based on certain criteria.
# Out:
#                               Employees      Profits  Revenue
# Sector
# Aerospace & Defense              968057  1437.100000   357940
# Apparel                          346397   549.066667    95968
# Business Services               1361050   553.470588   272195
# Chemicals                        463651   754.266667   243897
# Energy                          1188927  -602.024590  1517809
# Engineering & Construction       406708   204.000000   153983
# Financials                      3359948  1872.007194  2217159
# Food and Drug Stores            1395398  1117.266667   483769
# Food, Beverages & Tobacco       1211632  1195.744186   555967
# Health Care                     2678289  1414.853333  1614707
# Hotels, Resturants & Leisure    2484245   827.880000   169546
# Household Products               646038   515.285714   234737
# Industrials                     1545229   451.391304   497581
# Materials                        638123   102.976744   259145
# ...

# %%
#series

# %%
import pandas as pd
import numpy as np

# %%
ice_cream=["Strawberry","Choco","Vanilla","mint"]
pd.series(ice_cream)  # Ensure that 'S' is capital in series or it will show error
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[82], line 2
#       1 ice_cream=["Strawberry","Choco","Vanilla","mint"]
# ----> 2 pd.series(ice_cream)
#
# AttributeError: module 'pandas' has no attribute 'series'

# %%
ice_cream=["Strawberry","Choco","Vanilla","mint"]
pd.Series(ice_cream)  #data type here is object
# Out:
# 0    Strawberry
# 1         Choco
# 2       Vanilla
# 3          mint
# dtype: object

# %%
type(ice_cream)
# Out:
# list

# %%
lotter_number=[12,45,67,89,9]
pd.Series(lotter_number) # data type integers
# Out:
# 0    12
# 1    45
# 2    67
# 3    89
# 4     9
# dtype: int64

# %%
type(lotter_number)
# Out:
# list

# %%
# checking for missing data using isna

# %%
print(data_frame.isna())
# Out:
#     Name  Register  Class  Score
# 0  False     False  False  False
# 1   True     False   True  False
# 2  False     False  False  False
# 3   True     False  False  False
# 4  False     False  False  False

# %%
data=data_frame.replace(to_replace=np.nan,value=0)
print(data)
# Out:
#      Name  Register Class  Score
# 0  Teisya         1     A     45
# 1       0         2     0     67
# 2    Rain         3     B     89
# 3       0         4     C     98
# 4   Power         5     D     74
